# %% [markdown]
# # 05 Track Characteristics for 2026
#
# The 2026 regulations are a complete reset. New aero, new power units, 30kg lighter cars. I can't use 2024-2025 lap times or team performance to predict anything.
#
# But track geometry doesn't change. Monaco will still have tight corners, Monza will still have long straights. That's what I extract here.
#
# When I get 2026 testing data showing which cars are fast where, we'll match those car profiles against these track profiles to predict which tracks suit which teams.

# %% [markdown]
# ## Setup

# %%
import fastf1 as ff1
import pandas as pd
from pathlib import Path
import json

import logging
logging.getLogger("fastf1").setLevel(logging.ERROR)

import sys

PROJECT_ROOT = Path.cwd().parents[0]
sys.path.append(str(PROJECT_ROOT))

from src.helpers.circuit_utils import get_circuits
from src.helpers.track_extraction import (
    extract_track_profile,
    identify_street_circuits,
    calculate_track_z_scores,
    describe_track_profile
)

ff1.Cache.enable_cache('../data/raw/.fastf1_cache')

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

season = 2025

# %% [markdown]
# ## Extract Track Geometry from 2025
#
# Using qualifying sessions because they have clean laps and representative data.

# %% [markdown]
# Using helper functions from `src/helpers/track_extraction.py` for extraction.

# %% [markdown]
# ### Querying the data

# %%
# Extract from all 2025 races
schedule = ff1.get_event_schedule(season)
races = schedule[schedule['EventFormat'] != 'testing']

track_profiles = {}
failed = []

for idx, race in races.iterrows():
    event_name = race['EventName']
    print(f"Processing {event_name}...")
    
    try:
        session = ff1.get_session(season, event_name, 'Q')
        session.load(telemetry=True, laps=True)
        
        profile = extract_track_profile(season, session)
        
        if profile:
            track_profiles[event_name] = profile
            print(f" 🟢 Done")
        else:
            failed.append(event_name)
            print(f" 🔴 Failed - no metrics")
            
    except Exception as e:
        failed.append(event_name)
        print(f" 🔴 Failed: {e}")

print(f"\n🟢 Extracted {len(track_profiles)} tracks")
if failed:
    print(f"🔴 Failed: {failed}")
# Out:
# Processing Australian Grand Prix...
#  🟢 Done
# Processing Chinese Grand Prix...
#  🟢 Done
# Processing Japanese Grand Prix...
#  🟢 Done
# Processing Bahrain Grand Prix...
#  🟢 Done
# Processing Saudi Arabian Grand Prix...
#  🟢 Done
# Processing Miami Grand Prix...
#  🟢 Done
# Processing Emilia Romagna Grand Prix...
#  🟢 Done
# Processing Monaco Grand Prix...
#  🟢 Done
# Processing Spanish Grand Prix...
#  🟢 Done
# Processing Canadian Grand Prix...
#  🟢 Done
# Processing Austrian Grand Prix...
#  🟢 Done
# Processing British Grand Prix...
#  🟢 Done
# Processing Belgian Grand Prix...
#  🟢 Done
# Processing Hungarian Grand Prix...
#  🟢 Done
# Processing Dutch Grand Prix...
#  🟢 Done
# Processing Italian Grand Prix...
#  🟢 Done
# Processing Azerbaijan Grand Prix...
#  🟢 Done
# Processing Singapore Grand Prix...
#  🟢 Done
# Processing United States Grand Prix...
#  🟢 Done
# Processing Mexico City Grand Prix...
#  🟢 Done
# Processing São Paulo Grand Prix...
#  🟢 Done
# Processing Las Vegas Grand Prix...
#  🟢 Done
# Processing Qatar Grand Prix...
#  🟢 Done
# Processing Abu Dhabi Grand Prix...
#  🟢 Done
#
# 🟢 Extracted 24 tracks

# %% [markdown]
# ### Getting main characteristics of each circuit

# %%
# Add circuit metadata
circuits_season = get_circuits(2025)

for event_name, profile in track_profiles.items():
    # Match circuit info
    circuit_match = circuits_season[circuits_season['circuitName'].str.contains(event_name.split()[0], na=False)]
    
    if len(circuit_match) > 0:
        circuit = circuit_match.iloc[0]
        profile['altitude_m'] = circuit['altitude']
        profile['location'] = circuit['location']
        profile['country'] = circuit['country']

df_tracks = pd.DataFrame.from_dict(track_profiles, orient='index')
df_tracks
# Out:
#                                           track_name  slow_corner_pct  \
# Australian Grand Prix          Australian Grand Prix         0.046763
# Chinese Grand Prix                Chinese Grand Prix         0.159639
# Japanese Grand Prix              Japanese Grand Prix         0.074303
# Bahrain Grand Prix                Bahrain Grand Prix         0.106383
# Saudi Arabian Grand Prix    Saudi Arabian Grand Prix         0.050314
# Miami Grand Prix                    Miami Grand Prix         0.180685
# Emilia Romagna Grand Prix  Emilia Romagna Grand Prix         0.044280
# Monaco Grand Prix                  Monaco Grand Prix         0.315175
# Spanish Grand Prix                Spanish Grand Prix         0.022140
# Canadian Grand Prix              Canadian Grand Prix         0.115672
# Austrian Grand Prix              Austrian Grand Prix         0.068085
# British Grand Prix                British Grand Prix         0.072555
# Belgian Grand Prix                Belgian Grand Prix         0.074866
# Hungarian Grand Prix            Hungarian Grand Prix         0.062500
# Dutch Grand Prix                    Dutch Grand Prix         0.038314
# Italian Grand Prix                Italian Grand Prix         0.065744
# Azerbaijan Grand Prix          Azerbaijan Grand Prix         0.179688
# Singapore Grand Prix            Singapore Grand Prix         0.149068
# United States Grand Prix    United States Grand Prix         0.146552
# Mexico City Grand Prix        Mexico City Grand Prix         0.241877
# São Paulo Grand Prix            São Paulo Grand Prix         0.128676
# Las Vegas Grand Prix            Las Vegas Grand Prix         0.272040
# Qatar Grand Prix                    Qatar Grand Prix         0.026316
# Abu Dhabi Grand Prix            Abu Dhabi Grand Prix         0.090032
#
#                            medium_corner_pct  fast_corner_pct  \
# Australian Grand Prix               0.172662         0.780576
# Chinese Grand Prix                  0.237952         0.602410
# Japanese Grand Prix                 0.139319         0.786378
# Bahrain Grand Prix                  0.273556         0.620061
# Saudi Arabian Grand Prix            0.150943         0.798742
# Miami Grand Prix                    0.205607         0.613707
# Emilia Romagna Grand Prix           0.254613         0.701107
# Monaco Grand Prix                   0.334630         0.350195
# Spanish Grand Prix                  0.291513         0.686347
# Canadian Grand Prix                 0.276119         0.608209
# Austrian Grand Prix                 0.136170         0.795745
# British Grand Prix                  0.208202         0.719243
# Belgian Grand Prix                  0.163102         0.762032
# Hungarian Grand Prix                0.385417         0.552083
# Dutch Grand Prix                    0.302682         0.659004
# Italian Grand Prix                  0.103806         0.830450
# Azerbaijan Grand Prix               0.286458         0.533854
# Singapore Grand Prix                0.388199         0.462733
# United States Grand Prix            0.250000         0.603448
# Mexico City Grand Prix              0.277978         0.480144
# São Paulo Grand Prix                0.257353         0.613971
# Las Vegas Grand Prix                0.214106         0.513854
# Qatar Grand Prix                    0.187500         0.786184
# Abu Dhabi Grand Prix                0.234727         0.675241
#
#                            full_throttle_pct  top_speed_kmh  energy_score  \
# Australian Grand Prix               0.712230          329.0      4.096134
# Chinese Grand Prix                  0.575301          330.0      3.788902
# Japanese Grand Prix                 0.687307          325.0      3.857212
# Bahrain Grand Prix                  0.595745          315.0      3.616952
# Saudi Arabian Grand Prix            0.764151          338.0      4.072838
# Miami Grand Prix                    0.613707          340.0      4.087835
# Emilia Romagna Grand Prix           0.678967          323.0      3.759230
# Monaco Grand Prix                   0.435798          289.0      2.817060
# Spanish Grand Prix                  0.638376          328.0      3.716752
# Canadian Grand Prix                 0.664179          332.0      3.827475
# Austrian Grand Prix                 0.668085          324.0      3.962830
# British Grand Prix                  0.662461          324.0      4.226695
# Belgian Grand Prix                  0.687166          339.0      4.247661
# Hungarian Grand Prix                0.541667          318.0      3.290138
# Dutch Grand Prix                    0.590038          326.0      3.616444
# Italian Grand Prix                  0.768166          348.0      4.519313
# Azerbaijan Grand Prix               0.614583          339.0      3.816471
# Singapore Grand Prix                0.524845          316.0      3.279798
# United States Grand Prix            0.583333          324.0      3.597017
# Mexico City Grand Prix              0.490975          351.0      3.662852
# São Paulo Grand Prix                0.588235          336.0      3.861933
# Las Vegas Grand Prix                0.488665          331.0      3.921072
# Qatar Grand Prix                    0.687500          327.0      3.692062
# Abu Dhabi Grand Prix                0.672026          331.0      3.883559
#
#                            braking_zones  extracted_from  avg_speed_loss_kmh  \
# Australian Grand Prix                 11            2025          100.333333
# Chinese Grand Prix                     8            2025          111.375000
# Japanese Grand Prix                    7            2025          100.500000
# Bahrain Grand Prix                    10            2025          163.000000
# Saudi Arabian Grand Prix              10            2025          106.714286
# Miami Grand Prix                      10            2025          122.285714
# Emilia Romagna Grand Prix              9            2025          100.625000
# Monaco Grand Prix                      8            2025           61.363636
# Spanish Grand Prix                     6            2025          122.666667
# Canadian Grand Prix                   15            2025          174.666667
# Austrian Grand Prix                    8            2025          131.166667
# British Grand Prix                     5            2025           82.571429
# Belgian Grand Prix                    11            2025           84.000000
# Hungarian Grand Prix                   7            2025           84.000000
# Dutch Grand Prix                       5            2025           88.666667
# Italian Grand Prix                    11            2025          105.166667
# Azerbaijan Grand Prix                 15            2025          142.000000
# Singapore Grand Prix                  13            2025          124.000000
# United States Grand Prix              14            2025          121.750000
# Mexico City Grand Prix                 6            2025           83.375000
# São Paulo Grand Prix                   6            2025           89.857143
# Las Vegas Grand Prix                   8            2025          112.857143
# Qatar Grand Prix                       7            2025           81.000000
# Abu Dhabi Grand Prix                  10            2025          150.857143
#
#                            max_speed_loss_kmh  min_corner_speed_kmh  \
# Australian Grand Prix                   193.0                  98.0
# Chinese Grand Prix                      263.0                  65.0
# Japanese Grand Prix                     209.0                  77.0
# Bahrain Grand Prix                      248.0                  67.0
# Saudi Arabian Grand Prix                225.0                  88.0
# Miami Grand Prix                        271.0                  69.0
# Emilia Romagna Grand Prix               180.0                 104.0
# Monaco Grand Prix                       168.0                  46.0
# Spanish Grand Prix                      195.0                 107.0
# Canadian Grand Prix                     232.0                  65.0
# Austrian Grand Prix                     244.0                  74.0
# British Grand Prix                      200.0                  89.0
# Belgian Grand Prix                      165.0                  75.0
# Hungarian Grand Prix                    220.0                  98.0
# Dutch Grand Prix                        200.0                 101.0
# Italian Grand Prix                      217.0                  73.0
# Azerbaijan Grand Prix                   220.0                  72.0
# Singapore Grand Prix                    202.0                  65.0
# United States Grand Prix                228.0                  80.0
# Mexico City Grand Prix                  179.0                  68.0
# São Paulo Grand Prix                    162.0                  85.0
# Las Vegas Grand Prix                    262.0                  69.0
# Qatar Grand Prix                        151.0                  99.0
# Abu Dhabi Grand Prix                    263.0                  68.0
#
#                            heavy_braking_pct  medium_braking_pct  \
# Australian Grand Prix               0.666667            0.166667
# Chinese Grand Prix                  0.625000            0.000000
# Japanese Grand Prix                 0.500000            0.250000
# Bahrain Grand Prix                  0.875000            0.125000
# Saudi Arabian Grand Prix            0.714286            0.000000
# Miami Grand Prix                    0.428571            0.285714
# Emilia Romagna Grand Prix           0.625000            0.000000
# Monaco Grand Prix                   0.363636            0.181818
# Spanish Grand Prix                  0.833333            0.000000
# Canadian Grand Prix                 1.000000            0.000000
# Austrian Grand Prix                 0.833333            0.000000
# British Grand Prix                  0.571429            0.000000
# Belgian Grand Prix                  0.571429            0.142857
# Hungarian Grand Prix                0.545455            0.181818
# Dutch Grand Prix                    0.666667            0.166667
# Italian Grand Prix                  0.666667            0.166667
# Azerbaijan Grand Prix               0.800000            0.100000
# Singapore Grand Prix                0.833333            0.166667
# United States Grand Prix            0.875000            0.000000
# Mexico City Grand Prix              0.625000            0.250000
# São Paulo Grand Prix                0.571429            0.000000
# Las Vegas Grand Prix                0.428571            0.142857
# Qatar Grand Prix                    0.750000            0.125000
# Abu Dhabi Grand Prix                0.857143            0.000000
#
#                            light_braking_pct  total_corners  corner_density  \
# Australian Grand Prix               0.166667              6        1.151868
# Chinese Grand Prix                  0.375000              8        1.487735
# Japanese Grand Prix                 0.250000              8        1.383622
# Bahrain Grand Prix                  0.000000              8        1.494668
# Saudi Arabian Grand Prix            0.285714              7        1.147214
# Miami Grand Prix                    0.285714              7        1.311169
# Emilia Romagna Grand Prix           0.375000              8        1.644897
# Monaco Grand Prix                   0.454545             11        3.356726
# Spanish Grand Prix                  0.166667              6        1.296212
# Canadian Grand Prix                 0.000000              6        1.386826
# Austrian Grand Prix                 0.166667              6        1.395851
# British Grand Prix                  0.428571              7        1.204036
# Belgian Grand Prix                  0.285714              7        1.006118
# Hungarian Grand Prix                0.272727             11        2.524424
# Dutch Grand Prix                    0.166667              6        1.418065
# Italian Grand Prix                  0.166667              6        1.042916
# Azerbaijan Grand Prix               0.100000             10        1.685148
# Singapore Grand Prix                0.000000             12        2.459611
# United States Grand Prix            0.125000              8        1.472948
# Mexico City Grand Prix              0.125000              8        1.891816
# São Paulo Grand Prix                0.428571              7        1.664771
# Las Vegas Grand Prix                0.428571              7        1.139509
# Qatar Grand Prix                    0.125000              8        1.494031
# Abu Dhabi Grand Prix                0.142857              7        1.340085
#
#                            altitude_m     location  country
# Australian Grand Prix             NaN          NaN      NaN
# Chinese Grand Prix                NaN          NaN      NaN
# Japanese Grand Prix               NaN          NaN      NaN
# Bahrain Grand Prix                8.0       Sakhir  Bahrain
# Saudi Arabian Grand Prix          NaN          NaN      NaN
# Miami Grand Prix                  5.0        Miami      USA
# Emilia Romagna Grand Prix         NaN          NaN      NaN
# Monaco Grand Prix                16.0  Monte Carlo   Monaco
# Spanish Grand Prix                NaN          NaN      NaN
# Canadian Grand Prix               NaN          NaN      NaN
# Austrian Grand Prix               NaN          NaN      NaN
# British Grand Prix                NaN          NaN      NaN
# Belgian Grand Prix                NaN          NaN      NaN
# Hungarian Grand Prix              NaN          NaN      NaN
# Dutch Grand Prix                  NaN          NaN      NaN
# Italian Grand Prix                NaN          NaN      NaN
# Azerbaijan Grand Prix             NaN          NaN      NaN
# Singapore Grand Prix              NaN          NaN      NaN
# United States Grand Prix          NaN          NaN      NaN
# Mexico City Grand Prix            NaN          NaN      NaN
# São Paulo Grand Prix              NaN          NaN      NaN
# Las Vegas Grand Prix            644.0    Las Vegas      USA
# Qatar Grand Prix                  NaN          NaN      NaN
# Abu Dhabi Grand Prix              NaN          NaN      NaN

# %%
# Identify street circuits
df_tracks['is_street_circuit'] = df_tracks.index.map(identify_street_circuits)

print(f"Street circuits identified: {df_tracks[df_tracks['is_street_circuit']==1].index.tolist()}")
# Out:
# Street circuits identified: ['Saudi Arabian Grand Prix', 'Miami Grand Prix', 'Monaco Grand Prix', 'Azerbaijan Grand Prix', 'Singapore Grand Prix', 'Las Vegas Grand Prix']

# %% [markdown]
# ## Multi-Dimensional Track Profiling
#
# Tracks aren't just "slow-corner" or "high-speed". They're somewhere in between on multiple dimensions.
#
# Two corners at 120 km/h can be completely different:
# - **Monaco T1**: Entry 180 km/h → Apex 60 km/h → Exit 110 km/h (120 km/h lost)
# - **Silverstone Copse**: Entry 290 km/h → Apex 270 km/h → Exit 280 km/h (20 km/h lost)
#
# Same speed classification, totally different demands. Monaco needs traction, Silverstone needs aero grip.
#
# I capture multiple dimensions:
# - **Corner speed** - What speed ranges the track operates in
# - **Corner density** - How many corners per km (Monaco: ~9/km, Monza: ~2/km)
# - **Tightest corner** - Slowest point on track (Monaco: ~50 km/h, most tracks: ~70+ km/h)
# - **Corner severity** - How much braking demanded (Canada: 175 km/h avg loss, Monaco: 60 km/h)
# - **Street circuit** - Binary flag for unique characteristics (tight, unforgiving, low grip)
#
# I use z-scores to capture this. A z-score tells you how many standard deviations a track is from average:
# - z = +2.0 means 2 std dev above average (extreme)
# - z = 0.0 means exactly average
# - z = -1.0 means 1 std dev below average
#
# When I extract car characteristics from 2026 testing, we'll use the same z-score approach. Then I can mathematically match cars to tracks.

# %%
# Calculate z-scores for track characteristics
features = [
    # Corner speed distribution
    'slow_corner_pct',
    'medium_corner_pct',
    'fast_corner_pct',
    
    # Corner characteristics
    'corner_density',
    'min_corner_speed_kmh',
    'avg_speed_loss_kmh',
    'heavy_braking_pct',
    
    # Power characteristics
    'full_throttle_pct',
    
    # Tire stress
    'energy_score',
    
    # Complexity
    'braking_zones',
    
    # Track type
    'is_street_circuit'
]

# Calculate z-scores using helper function
df_tracks, scaler_params = calculate_track_z_scores(df_tracks, features)

print(f"Tracks with complete data: {len(df_tracks)}")
print("\nZ-score statistics:")
print(df_tracks[[f'{f}_z' for f in features]].describe())
# Out:
# Tracks with complete data: 24
#
# Z-score statistics:
#        slow_corner_pct_z  medium_corner_pct_z  fast_corner_pct_z  \
# count       2.400000e+01         2.400000e+01       2.400000e+01
# mean       -1.110223e-16        -2.636780e-16      -2.960595e-16
# std         1.021508e+00         1.021508e+00       1.021508e+00
# min        -1.187742e+00        -1.843828e+00      -2.436019e+00
# 25%        -7.043322e-01        -7.518308e-01      -4.713647e-01
# 50%        -4.064149e-01         6.986027e-02      -6.386050e-02
# 75%         4.908974e-01         5.630274e-01       9.784710e-01
# max         2.608641e+00         2.038885e+00       1.501392e+00
#
#        corner_density_z  min_corner_speed_kmh_z  avg_speed_loss_kmh_z  \
# count      2.400000e+01               24.000000          2.400000e+01
# mean      -1.202742e-16                0.000000         -4.070818e-16
# std        1.021508e+00                1.021508          1.021508e+00
# min       -1.050222e+00               -2.171977         -1.784590e+00
# 25%       -5.423477e-01               -0.734880         -8.295075e-01
# 50%       -2.879067e-01               -0.310282         -1.556500e-01
# 75%        1.740553e-01                0.783872          4.677443e-01
# max        3.420156e+00                1.812703          2.355763e+00
#
#        heavy_braking_pct_z  full_throttle_pct_z  energy_score_z  \
# count         2.400000e+01         2.400000e+01    2.400000e+01
# mean          7.771561e-16         7.586524e-16    2.451743e-16
# std           1.021508e+00         1.021508e+00    1.021508e+00
# min          -1.940339e+00        -2.240119e+00   -2.856881e+00
# 25%          -6.500836e-01        -4.914937e-01   -4.338404e-01
# 50%          -5.871668e-02         5.107265e-02    6.160813e-02
# 75%           9.761753e-01         7.063723e-01    5.505598e-01
# max           2.011067e+00         1.753541e+00    2.086836e+00
#
#        braking_zones_z  is_street_circuit_z
# count     2.400000e+01         2.400000e+01
# mean      2.590520e-16        -3.700743e-17
# std       1.021508e+00         1.021508e+00
# min      -1.431496e+00        -5.773503e-01
# 25%      -7.443778e-01        -5.773503e-01
# 50%      -2.290393e-01        -5.773503e-01
# 75%       6.298582e-01         0.000000e+00
# max       2.004094e+00         1.732051e+00

# %% [markdown]
# ## What Makes Each Track Unusual?
#
# Looking at tracks with strong characteristics (z-score > 1.0)

# %%
# Generate track profile descriptions
df_tracks['profile_description'] = df_tracks.apply(describe_track_profile, axis=1)

# Show tracks with strong characteristics
print("Tracks with Distinctive Profiles:")
print("="*80)
for track in df_tracks.index:
    row = df_tracks.loc[track]
    if 'Balanced' not in row['profile_description']:
        print(f"\n{track}")
        print(f"  {row['profile_description']}")
        print(f"  Speed:     slow={row['slow_corner_pct_z']:+.2f}  med={row['medium_corner_pct_z']:+.2f}  fast={row['fast_corner_pct_z']:+.2f}")
        print(f"  Corners:   density={row['corner_density_z']:+.2f}  min_speed={row['min_corner_speed_kmh_z']:+.2f}")
        print(f"  Severity:  avg_loss={row['avg_speed_loss_kmh_z']:+.2f}  heavy_braking={row['heavy_braking_pct_z']:+.2f}")
        print(f"  Power:     throttle={row['full_throttle_pct_z']:+.2f}")
        print(f"  Tires:     energy={row['energy_score_z']:+.2f}")
        print(f"  Raw:       corner_density={row['corner_density']:.2f}/km  min_speed={row['min_corner_speed_kmh']:.0f} km/h")
# Out:
# Tracks with Distinctive Profiles:
# ================================================================================
#
# Australian Grand Prix
#   Heavy high-speed, High throttle demand
#   Speed:     slow=-0.87  med=-0.90  fast=+1.09
#   Corners:   density=-0.77  min_speed=+1.22
#   Severity:  avg_loss=-0.36  heavy_braking=-0.06
#   Power:     throttle=+1.08
#   Tires:     energy=+0.86
#   Raw:       corner_density=1.15/km  min_speed=98 km/h
#
# Chinese Grand Prix
#   Above-average slow corners
#   Speed:     slow=+0.59  med=-0.01  fast=-0.37
#   Corners:   density=-0.13  min_speed=-0.93
#   Severity:  avg_loss=+0.04  heavy_braking=-0.32
#   Power:     throttle=-0.56
#   Tires:     energy=-0.03
#   Raw:       corner_density=1.49/km  min_speed=65 km/h
#
# Japanese Grand Prix
#   Heavy high-speed
#   Speed:     slow=-0.51  med=-1.36  fast=+1.14
#   Corners:   density=-0.33  min_speed=-0.15
#   Severity:  avg_loss=-0.35  heavy_braking=-1.09
#   Power:     throttle=+0.78
#   Tires:     energy=+0.16
#   Raw:       corner_density=1.38/km  min_speed=77 km/h
#
# Bahrain Grand Prix
#   EXTREME braking demands, Traction-limited
#   Speed:     slow=-0.10  med=+0.47  fast=-0.22
#   Corners:   density=-0.12  min_speed=-0.80
#   Severity:  avg_loss=+1.93  heavy_braking=+1.23
#   Power:     throttle=-0.32
#   Tires:     energy=-0.53
#   Raw:       corner_density=1.49/km  min_speed=67 km/h
#
# Saudi Arabian Grand Prix
#   Heavy high-speed, High throttle demand, Street circuit
#   Speed:     slow=-0.82  med=-1.20  fast=+1.24
#   Corners:   density=-0.78  min_speed=+0.57
#   Severity:  avg_loss=-0.13  heavy_braking=+0.24
#   Power:     throttle=+1.71
#   Tires:     energy=+0.79
#   Raw:       corner_density=1.15/km  min_speed=88 km/h
#
# Miami Grand Prix
#   Above-average slow corners, Street circuit
#   Speed:     slow=+0.87  med=-0.45  fast=-0.28
#   Corners:   density=-0.47  min_speed=-0.67
#   Severity:  avg_loss=+0.44  heavy_braking=-1.54
#   Power:     throttle=-0.10
#   Tires:     energy=+0.83
#   Raw:       corner_density=1.31/km  min_speed=69 km/h
#
# Monaco Grand Prix
#   EXTREME slow corners, Heavy technical sections, EXTREME corner density, EXTREME tight corners, Flow-focused, Street circuit
#   Speed:     slow=+2.61  med=+1.31  fast=-2.44
#   Corners:   density=+3.42  min_speed=-2.17
#   Severity:  avg_loss=-1.78  heavy_braking=-1.94
#   Power:     throttle=-2.24
#   Tires:     energy=-2.86
#   Raw:       corner_density=3.36/km  min_speed=46 km/h
#
# Spanish Grand Prix
#   Above-average technical
#   Speed:     slow=-1.19  med=+0.72  fast=+0.32
#   Corners:   density=-0.50  min_speed=+1.81
#   Severity:  avg_loss=+0.46  heavy_braking=+0.98
#   Power:     throttle=+0.19
#   Tires:     energy=-0.24
#   Raw:       corner_density=1.30/km  min_speed=107 km/h
#
# Canadian Grand Prix
#   Above-average technical, EXTREME braking demands, Traction-limited, High complexity
#   Speed:     slow=+0.02  med=+0.51  fast=-0.32
#   Corners:   density=-0.33  min_speed=-0.93
#   Severity:  avg_loss=+2.36  heavy_braking=+2.01
#   Power:     throttle=+0.50
#   Tires:     energy=+0.08
#   Raw:       corner_density=1.39/km  min_speed=65 km/h
#
# Austrian Grand Prix
#   Heavy high-speed
#   Speed:     slow=-0.59  med=-1.40  fast=+1.22
#   Corners:   density=-0.31  min_speed=-0.34
#   Severity:  avg_loss=+0.77  heavy_braking=+0.98
#   Power:     throttle=+0.55
#   Tires:     energy=+0.47
#   Raw:       corner_density=1.40/km  min_speed=74 km/h
#
# British Grand Prix
#   Above-average high-speed, Flow-focused, High tire stress
#   Speed:     slow=-0.53  med=-0.42  fast=+0.59
#   Corners:   density=-0.67  min_speed=+0.64
#   Severity:  avg_loss=-1.01  heavy_braking=-0.65
#   Power:     throttle=+0.48
#   Tires:     energy=+1.24
#   Raw:       corner_density=1.20/km  min_speed=89 km/h
#
# Belgian Grand Prix
#   Above-average high-speed, High tire stress
#   Speed:     slow=-0.50  med=-1.03  fast=+0.94
#   Corners:   density=-1.05  min_speed=-0.28
#   Severity:  avg_loss=-0.96  heavy_braking=-0.65
#   Power:     throttle=+0.78
#   Tires:     energy=+1.30
#   Raw:       corner_density=1.01/km  min_speed=75 km/h
#
# Hungarian Grand Prix
#   EXTREME technical sections, EXTREME corner density
#   Speed:     slow=-0.66  med=+2.00  fast=-0.78
#   Corners:   density=+1.84  min_speed=+1.22
#   Severity:  avg_loss=-0.96  heavy_braking=-0.81
#   Power:     throttle=-0.97
#   Tires:     energy=-1.48
#   Raw:       corner_density=2.52/km  min_speed=98 km/h
#
# Dutch Grand Prix
#   Above-average technical
#   Speed:     slow=-0.98  med=+0.87  fast=+0.10
#   Corners:   density=-0.27  min_speed=+1.42
#   Severity:  avg_loss=-0.79  heavy_braking=-0.06
#   Power:     throttle=-0.39
#   Tires:     energy=-0.54
#   Raw:       corner_density=1.42/km  min_speed=101 km/h
#
# Italian Grand Prix
#   EXTREME high-speed, High throttle demand, EXTREME tire stress
#   Speed:     slow=-0.62  med=-1.84  fast=+1.50
#   Corners:   density=-0.98  min_speed=-0.41
#   Severity:  avg_loss=-0.18  heavy_braking=-0.06
#   Power:     throttle=+1.75
#   Tires:     energy=+2.09
#   Raw:       corner_density=1.04/km  min_speed=73 km/h
#
# Azerbaijan Grand Prix
#   Above-average slow corners, Above-average technical, Heavy braking, High complexity, Street circuit
#   Speed:     slow=+0.85  med=+0.65  fast=-0.93
#   Corners:   density=+0.24  min_speed=-0.47
#   Severity:  avg_loss=+1.16  heavy_braking=+0.77
#   Power:     throttle=-0.09
#   Tires:     energy=+0.05
#   Raw:       corner_density=1.69/km  min_speed=72 km/h
#
# Singapore Grand Prix
#   EXTREME technical sections, EXTREME corner density, High complexity, Street circuit
#   Speed:     slow=+0.46  med=+2.04  fast=-1.51
#   Corners:   density=+1.71  min_speed=-0.93
#   Severity:  avg_loss=+0.50  heavy_braking=+0.98
#   Power:     throttle=-1.17
#   Tires:     energy=-1.51
#   Raw:       corner_density=2.46/km  min_speed=65 km/h
#
# United States Grand Prix
#   Traction-limited, High complexity
#   Speed:     slow=+0.42  med=+0.15  fast=-0.36
#   Corners:   density=-0.16  min_speed=+0.05
#   Severity:  avg_loss=+0.42  heavy_braking=+1.23
#   Power:     throttle=-0.47
#   Tires:     energy=-0.59
#   Raw:       corner_density=1.47/km  min_speed=80 km/h
#
# Mexico City Grand Prix
#   EXTREME slow corners, Above-average technical
#   Speed:     slow=+1.66  med=+0.53  fast=-1.37
#   Corners:   density=+0.63  min_speed=-0.73
#   Severity:  avg_loss=-0.98  heavy_braking=-0.32
#   Power:     throttle=-1.58
#   Tires:     energy=-0.40
#   Raw:       corner_density=1.89/km  min_speed=68 km/h
#
# Las Vegas Grand Prix
#   EXTREME slow corners, Street circuit
#   Speed:     slow=+2.05  med=-0.34  fast=-1.09
#   Corners:   density=-0.80  min_speed=-0.67
#   Severity:  avg_loss=+0.10  heavy_braking=-1.54
#   Power:     throttle=-1.60
#   Tires:     energy=+0.35
#   Raw:       corner_density=1.14/km  min_speed=69 km/h
#
# Qatar Grand Prix
#   Heavy high-speed, Flow-focused
#   Speed:     slow=-1.13  med=-0.70  fast=+1.14
#   Corners:   density=-0.12  min_speed=+1.29
#   Severity:  avg_loss=-1.07  heavy_braking=+0.46
#   Power:     throttle=+0.78
#   Tires:     energy=-0.32
#   Raw:       corner_density=1.49/km  min_speed=99 km/h
#
# Abu Dhabi Grand Prix
#   Heavy braking, Traction-limited
#   Speed:     slow=-0.31  med=-0.06  fast=+0.23
#   Corners:   density=-0.42  min_speed=-0.73
#   Severity:  avg_loss=+1.49  heavy_braking=+1.12
#   Power:     throttle=+0.60
#   Tires:     energy=+0.24
#   Raw:       corner_density=1.34/km  min_speed=68 km/h

# %% [markdown]
# ## Track Rankings
#
# Simple sorted lists for quick reference.

# %%
print("SLOW-CORNER RANKING (Top 8):")
print("-" * 80)
top_slow = df_tracks.nlargest(8, 'slow_corner_pct')
for i, (track, row) in enumerate(top_slow.iterrows(), 1):
    print(f"{i}. {track:30s} {row['slow_corner_pct']:6.1%} (z={row['slow_corner_pct_z']:+.2f})")

print("\nMEDIUM-CORNER RANKING (Top 8):")
print("-" * 80)
top_med = df_tracks.nlargest(8, 'medium_corner_pct')
for i, (track, row) in enumerate(top_med.iterrows(), 1):
    print(f"{i}. {track:30s} {row['medium_corner_pct']:6.1%} (z={row['medium_corner_pct_z']:+.2f})")

print("\nFAST-CORNER RANKING (Top 8):")
print("-" * 80)
top_fast = df_tracks.nlargest(8, 'fast_corner_pct')
for i, (track, row) in enumerate(top_fast.iterrows(), 1):
    print(f"{i}. {track:30s} {row['fast_corner_pct']:6.1%} (z={row['fast_corner_pct_z']:+.2f})")

print("\nCORNER DENSITY RANKING (Top 8 - most corners per km):")
print("-" * 80)
top_density = df_tracks.nlargest(8, 'corner_density')
for i, (track, row) in enumerate(top_density.iterrows(), 1):
    print(f"{i}. {track:30s} {row['corner_density']:5.2f} corners/km (z={row['corner_density_z']:+.2f})")

print("\nTIGHTEST CORNER RANKING (Top 8 - slowest apex speed):")
print("-" * 80)
top_tight = df_tracks.nsmallest(8, 'min_corner_speed_kmh')
for i, (track, row) in enumerate(top_tight.iterrows(), 1):
    print(f"{i}. {track:30s} {row['min_corner_speed_kmh']:5.0f} km/h min (z={row['min_corner_speed_kmh_z']:+.2f})")

print("\nCORNER SEVERITY RANKING (Top 8 - most speed lost):")
print("-" * 80)
top_severity = df_tracks.nlargest(8, 'avg_speed_loss_kmh')
for i, (track, row) in enumerate(top_severity.iterrows(), 1):
    print(f"{i}. {track:30s} {row['avg_speed_loss_kmh']:5.1f} km/h avg loss (z={row['avg_speed_loss_kmh_z']:+.2f})")

print("\nTRACTION-LIMITED RANKING (Top 8 - most heavy braking corners):")
print("-" * 80)
top_traction = df_tracks.nlargest(8, 'heavy_braking_pct')
for i, (track, row) in enumerate(top_traction.iterrows(), 1):
    print(f"{i}. {track:30s} {row['heavy_braking_pct']:5.1%} heavy corners (z={row['heavy_braking_pct_z']:+.2f})")

print("\nFULL THROTTLE RANKING (Top 8):")
print("-" * 80)
top_throttle = df_tracks.nlargest(8, 'full_throttle_pct')
for i, (track, row) in enumerate(top_throttle.iterrows(), 1):
    print(f"{i}. {track:30s} {row['full_throttle_pct']:6.1%} (z={row['full_throttle_pct_z']:+.2f})")

print("\nTIRE STRESS RANKING (Top 8):")
print("-" * 80)
top_energy = df_tracks.nlargest(8, 'energy_score')
for i, (track, row) in enumerate(top_energy.iterrows(), 1):
    print(f"{i}. {track:30s} energy={row['energy_score']:5.2f} (z={row['energy_score_z']:+.2f})")

print("\nSTREET CIRCUITS:")
print("-" * 80)
street = df_tracks[df_tracks['is_street_circuit'] == 1]
for track in street.index:
    print(f"  {track}")
# Out:
# SLOW-CORNER RANKING (Top 8):
# --------------------------------------------------------------------------------
# 1. Monaco Grand Prix               31.5% (z=+2.61)
# 2. Las Vegas Grand Prix            27.2% (z=+2.05)
# 3. Mexico City Grand Prix          24.2% (z=+1.66)
# 4. Miami Grand Prix                18.1% (z=+0.87)
# 5. Azerbaijan Grand Prix           18.0% (z=+0.85)
# 6. Chinese Grand Prix              16.0% (z=+0.59)
# 7. Singapore Grand Prix            14.9% (z=+0.46)
# 8. United States Grand Prix        14.7% (z=+0.42)
#
# MEDIUM-CORNER RANKING (Top 8):
# --------------------------------------------------------------------------------
# 1. Singapore Grand Prix            38.8% (z=+2.04)
# 2. Hungarian Grand Prix            38.5% (z=+2.00)
# 3. Monaco Grand Prix               33.5% (z=+1.31)
# 4. Dutch Grand Prix                30.3% (z=+0.87)
# 5. Spanish Grand Prix              29.2% (z=+0.72)
# 6. Azerbaijan Grand Prix           28.6% (z=+0.65)
# 7. Mexico City Grand Prix          27.8% (z=+0.53)
# 8. Canadian Grand Prix             27.6% (z=+0.51)
#
# FAST-CORNER RANKING (Top 8):
# --------------------------------------------------------------------------------
# 1. Italian Grand Prix              83.0% (z=+1.50)
# 2. Saudi Arabian Grand Prix        79.9% (z=+1.24)
# 3. Austrian Grand Prix             79.6% (z=+1.22)
# 4. Japanese Grand Prix             78.6% (z=+1.14)
# 5. Qatar Grand Prix                78.6% (z=+1.14)
# 6. Australian Grand Prix           78.1% (z=+1.09)
# 7. Belgian Grand Prix              76.2% (z=+0.94)
# 8. British Grand Prix              71.9% (z=+0.59)
#
# CORNER DENSITY RANKING (Top 8 - most corners per km):
# --------------------------------------------------------------------------------
# 1. Monaco Grand Prix               3.36 corners/km (z=+3.42)
# 2. Hungarian Grand Prix            2.52 corners/km (z=+1.84)
# 3. Singapore Grand Prix            2.46 corners/km (z=+1.71)
# 4. Mexico City Grand Prix          1.89 corners/km (z=+0.63)
# 5. Azerbaijan Grand Prix           1.69 corners/km (z=+0.24)
# 6. São Paulo Grand Prix            1.66 corners/km (z=+0.20)
# 7. Emilia Romagna Grand Prix       1.64 corners/km (z=+0.16)
# 8. Bahrain Grand Prix              1.49 corners/km (z=-0.12)
#
# TIGHTEST CORNER RANKING (Top 8 - slowest apex speed):
# --------------------------------------------------------------------------------
# 1. Monaco Grand Prix                 46 km/h min (z=-2.17)
# 2. Chinese Grand Prix                65 km/h min (z=-0.93)
# 3. Canadian Grand Prix               65 km/h min (z=-0.93)
# 4. Singapore Grand Prix              65 km/h min (z=-0.93)
# 5. Bahrain Grand Prix                67 km/h min (z=-0.80)
# 6. Mexico City Grand Prix            68 km/h min (z=-0.73)
# 7. Abu Dhabi Grand Prix              68 km/h min (z=-0.73)
# 8. Miami Grand Prix                  69 km/h min (z=-0.67)
#
# CORNER SEVERITY RANKING (Top 8 - most speed lost):
# --------------------------------------------------------------------------------
# 1. Canadian Grand Prix            174.7 km/h avg loss (z=+2.36)
# 2. Bahrain Grand Prix             163.0 km/h avg loss (z=+1.93)
# 3. Abu Dhabi Grand Prix           150.9 km/h avg loss (z=+1.49)
# 4. Azerbaijan Grand Prix          142.0 km/h avg loss (z=+1.16)
# 5. Austrian Grand Prix            131.2 km/h avg loss (z=+0.77)
# 6. Singapore Grand Prix           124.0 km/h avg loss (z=+0.50)
# 7. Spanish Grand Prix             122.7 km/h avg loss (z=+0.46)
# 8. Miami Grand Prix               122.3 km/h avg loss (z=+0.44)
#
# TRACTION-LIMITED RANKING (Top 8 - most heavy braking corners):
# --------------------------------------------------------------------------------
# 1. Canadian Grand Prix            100.0% heavy corners (z=+2.01)
# 2. Bahrain Grand Prix             87.5% heavy corners (z=+1.23)
# 3. United States Grand Prix       87.5% heavy corners (z=+1.23)
# 4. Abu Dhabi Grand Prix           85.7% heavy corners (z=+1.12)
# 5. Spanish Grand Prix             83.3% heavy corners (z=+0.98)
# 6. Austrian Grand Prix            83.3% heavy corners (z=+0.98)
# 7. Singapore Grand Prix           83.3% heavy corners (z=+0.98)
# 8. Azerbaijan Grand Prix          80.0% heavy corners (z=+0.77)
#
# FULL THROTTLE RANKING (Top 8):
# --------------------------------------------------------------------------------
# 1. Italian Grand Prix              76.8% (z=+1.75)
# 2. Saudi Arabian Grand Prix        76.4% (z=+1.71)
# 3. Australian Grand Prix           71.2% (z=+1.08)
# 4. Qatar Grand Prix                68.8% (z=+0.78)
# 5. Japanese Grand Prix             68.7% (z=+0.78)
# 6. Belgian Grand Prix              68.7% (z=+0.78)
# 7. Emilia Romagna Grand Prix       67.9% (z=+0.68)
# 8. Abu Dhabi Grand Prix            67.2% (z=+0.60)
#
# TIRE STRESS RANKING (Top 8):
# --------------------------------------------------------------------------------
# 1. Italian Grand Prix             energy= 4.52 (z=+2.09)
# 2. Belgian Grand Prix             energy= 4.25 (z=+1.30)
# 3. British Grand Prix             energy= 4.23 (z=+1.24)
# 4. Australian Grand Prix          energy= 4.10 (z=+0.86)
# 5. Miami Grand Prix               energy= 4.09 (z=+0.83)
# 6. Saudi Arabian Grand Prix       energy= 4.07 (z=+0.79)
# 7. Austrian Grand Prix            energy= 3.96 (z=+0.47)
# 8. Las Vegas Grand Prix           energy= 3.92 (z=+0.35)
#
# STREET CIRCUITS:
# --------------------------------------------------------------------------------
#   Saudi Arabian Grand Prix
#   Miami Grand Prix
#   Monaco Grand Prix
#   Azerbaijan Grand Prix
#   Singapore Grand Prix
#   Las Vegas Grand Prix

# %% [markdown]
# ## Save Track Database
#
# Saving both raw percentages and z-scores. When I extract car characteristics from 2026 testing, we'll compute z-scores the same way, then match cars to tracks mathematically.

# %%
# Save
output_dir = Path('../data/processed/testing_files/track_characteristics')
output_dir.mkdir(exist_ok=True)

# %%
output_file = output_dir / f'{season}_track_characteristics.json'

# Prepare data for saving
output_data = {
    'metadata': {
        'extracted_from': season,
        'session_type': 'Qualifying',
        'num_tracks': len(df_tracks),
        'features': features,
        'scaler_params': scaler_params
    },
    'tracks': {}
}

for track in df_tracks.index:
    row = df_tracks.loc[track]
    output_data['tracks'][track] = {
        # Raw percentages
        'slow_corner_pct': float(row['slow_corner_pct']),
        'medium_corner_pct': float(row['medium_corner_pct']),
        'fast_corner_pct': float(row['fast_corner_pct']),
        'full_throttle_pct': float(row['full_throttle_pct']),
        'energy_score': float(row['energy_score']),
        'braking_zones': int(row['braking_zones']),
        'top_speed_kmh': float(row['top_speed_kmh']),
        
        # Corner characteristics
        'corner_density': float(row['corner_density']),
        'min_corner_speed_kmh': float(row['min_corner_speed_kmh']),
        'avg_speed_loss_kmh': float(row['avg_speed_loss_kmh']),
        'max_speed_loss_kmh': float(row['max_speed_loss_kmh']),
        'heavy_braking_pct': float(row['heavy_braking_pct']),
        'medium_braking_pct': float(row['medium_braking_pct']),
        'light_braking_pct': float(row['light_braking_pct']),
        'total_corners': int(row['total_corners']),
        
        # Track type
        'is_street_circuit': int(row['is_street_circuit']),
        
        # Z-scores (for car-track matching)
        'slow_corner_z': float(row['slow_corner_pct_z']),
        'medium_corner_z': float(row['medium_corner_pct_z']),
        'fast_corner_z': float(row['fast_corner_pct_z']),
        'corner_density_z': float(row['corner_density_z']),
        'min_corner_speed_z': float(row['min_corner_speed_kmh_z']),
        'avg_speed_loss_z': float(row['avg_speed_loss_kmh_z']),
        'heavy_braking_z': float(row['heavy_braking_pct_z']),
        'full_throttle_z': float(row['full_throttle_pct_z']),
        'energy_z': float(row['energy_score_z']),
        'braking_zones_z': float(row['braking_zones_z']),
        'is_street_circuit_z': float(row['is_street_circuit_z']),
        
        # Metadata
        'altitude_m': float(row['altitude_m']) if pd.notna(row.get('altitude_m')) else None,
        'location': row.get('location', None),
        'country': row.get('country', None),
        'profile': row['profile_description']
    }

with open(output_file, 'w') as f:
    json.dump(output_data, f, indent=2)

# %%
# Also save as CSV for easy viewing
csv_cols = [
    # Raw values
    'slow_corner_pct', 'medium_corner_pct', 'fast_corner_pct',
    'full_throttle_pct', 'energy_score', 'braking_zones', 'top_speed_kmh',
    'corner_density', 'min_corner_speed_kmh', 'avg_speed_loss_kmh', 'max_speed_loss_kmh',
    'heavy_braking_pct', 'total_corners', 'is_street_circuit',
    # Z-scores
    'slow_corner_pct_z', 'medium_corner_pct_z', 'fast_corner_pct_z',
    'corner_density_z', 'min_corner_speed_kmh_z', 'avg_speed_loss_kmh_z', 'heavy_braking_pct_z',
    'full_throttle_pct_z', 'energy_score_z', 'braking_zones_z', 'is_street_circuit_z',
    # Metadata
    'altitude_m', 'location', 'country', 'profile_description'
]
df_tracks[csv_cols].to_csv(output_dir / f'{season}_track_characteristics.csv')
print(f"Also saved CSV to {output_dir / f'{season}_track_characteristics.csv'}")
# Out:
# Also saved CSV to ../data/processed/testing_files/track_characteristics/2025_track_characteristics.csv

# %% [markdown]
# ## Summary
#
# Track database built with 11 key characteristics:
#
# **Corner characteristics:**
# 1. Corner speed distribution (slow/medium/fast %)
# 2. Corner density (corners per km) - How twisty is the track?
# 3. Minimum corner speed - How tight are the tightest corners?
# 4. Average speed loss - How hard are the braking zones?
# 5. Heavy braking % - What % of corners are traction-limited?
#
# **Power & tire:**
# 6. Full throttle % - Power delivery demands
# 7. Energy score - Tire stress proxy
#
# **Other:**
# 8. Braking zones - Complexity
# 9. Street circuit flag - Different characteristics (tight, unforgiving, low grip)
#
# All characteristics stored as z-scores for car-track matching.
#
# **Key insights:**
# - Corner density captures "twisty" better than slow-corner %
# - Min corner speed captures "tight" better than average speed
# - Street circuits have unique demands beyond just corner types
